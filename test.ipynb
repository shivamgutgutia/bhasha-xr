# %%
# !pip install librosa
# Out:
# ...
#   Obtaining dependency information for librosa from https://files.pythonhosted.org/packages/e2/a2/4f639c1168d7aada749a896afb4892a831e2041bebdcf636aebfe9e86556/librosa-0.10.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for audioread>=2.1.9 from https://files.pythonhosted.org/packages/57/8d/30aa32745af16af0a9a650115fbe81bde7c610ed5c21b381fca0196f3a7f/audioread-3.0.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for numba>=0.51.0 from https://files.pythonhosted.org/packages/38/f0/ad848815b0adafcf5f238e728933950034355a8d59969772be1cd57606d8/numba-0.59.1-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for soundfile>=0.12.1 from https://files.pythonhosted.org/packages/50/ff/26a4ee48d0b66625a4e4028a055b9f25bc9d7c7b2d17d21a45137621a50d/soundfile-0.12.1-py2.py3-none-win_amd64.whl.metadata
# ...

# %%
import librosa
import numpy as np

def align_audio(audio1, audio2):
    # Compute cross-correlation
    xcorr = np.correlate(audio1, audio2, mode='full')
    delay = np.argmax(xcorr) - len(audio1) + 1

    # Shift the second audio to align with the first one
    if delay > 0:
        audio2_aligned = np.pad(audio2[:-delay], (delay, 0), mode='constant')
        audio1_aligned = audio1
    else:
        audio1_aligned = np.pad(audio1[:delay], (-delay, 0), mode='constant')
        audio2_aligned = audio2
    
    return audio1_aligned, audio2_aligned

def compare_audio(audio1_path, audio2_path):
    # Load audio files
    y1, sr1 = librosa.load(audio1_path)
    y2, sr2 = librosa.load(audio2_path)

    # Ensure both audio signals have the same duration
    min_len = min(len(y1), len(y2))
    y1 = y1[:min_len]
    y2 = y2[:min_len]

    # Align the audio files
    y1_aligned, y2_aligned = align_audio(y1, y2)

    # Extract MFCC features
    mfcc1 = librosa.feature.mfcc(y=y1_aligned, sr=sr1)
    mfcc2 = librosa.feature.mfcc(y=y2_aligned, sr=sr2)

    # Compute DTW distance
    dist = np.linalg.norm(mfcc1 - mfcc2, ord=1)

    # Normalize distance to get similarity score
    similarity_score = 1 / (1 + dist)

    return similarity_score

# Example usage
audio1_path = "thanni.wav"
audio2_path = "thannireal.wav"
similarity_score = compare_audio(audio1_path, audio2_path)
print("Similarity score:", similarity_score)
# Out:
# Similarity score: 0.0012982781332687575

# %%
def list_languages() -> dict:
    """Lists all available languages."""
    from google.cloud import translate_v2 as translate

    translate_client = translate.Client()

    results = translate_client.get_languages()

    for language in results:
        print("{name} ({language})".format(**language))

    return results
list_languages()
# Out:
# Afrikaans (af)
# Albanian (sq)
# Amharic (am)
# Arabic (ar)
# Armenian (hy)
# Assamese (as)
# Aymara (ay)
# Azerbaijani (az)
# Bambara (bm)
# Basque (eu)
# Belarusian (be)
# Bengali (bn)
# Bhojpuri (bho)
# Bosnian (bs)
# Bulgarian (bg)
# Catalan (ca)
# Cebuano (ceb)
# Chichewa (ny)
# Chinese (Simplified) (zh)
# Chinese (Traditional) (zh-TW)
# Corsican (co)
# Croatian (hr)
# Czech (cs)
# Danish (da)
# Divehi (dv)
# Dogri (doi)
# Dutch (nl)
# English (en)
# Esperanto (eo)
# Estonian (et)
# Ewe (ee)
# Filipino (tl)
# Finnish (fi)
# French (fr)
# Frisian (fy)
# Galician (gl)
# Ganda (lg)
# Georgian (ka)
# German (de)
# Greek (el)
# Guarani (gn)
# Gujarati (gu)
# Haitian Creole (ht)
# Hausa (ha)
# Hawaiian (haw)
# Hebrew (iw)
# Hindi (hi)
# Hmong (hmn)
# Hungarian (hu)
# Icelandic (is)
# Igbo (ig)
# Iloko (ilo)
# Indonesian (id)
# Irish Gaelic (ga)
# Italian (it)
# Japanese (ja)
# Javanese (jw)
# Kannada (kn)
# Kazakh (kk)
# Khmer (km)
# Kinyarwanda (rw)
# Konkani (gom)
# Korean (ko)
# ...
